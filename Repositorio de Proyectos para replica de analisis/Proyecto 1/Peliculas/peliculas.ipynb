# %%
import pandas as pd
import numpy as np
# Cargar el archivo CSV
data = pd.read_csv('peliculas.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 # Cargar el archivo CSV
# ----> 4 data = pd.read_csv('peliculas.csv')
#
# ...

# %%
data

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data.info()
#
# NameError: name 'data' is not defined

# %%
#duplicados
data = data.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #duplicados
# ----> 2 data = data.drop_duplicates()
#
# NameError: name 'data' is not defined

# %%
#valores vacios
data.isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #valores vacios
# ----> 2 data.isnull()
#
# NameError: name 'data' is not defined

# %%
data.isnull().sum() 
#contamos cuantos datos tenemos vacios
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data.isnull().sum()
#       2 #contamos cuantos datos tenemos vacios
#
# NameError: name 'data' is not defined

# %%
data = data.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data = data.dropna()
#
# NameError: name 'data' is not defined

# %%
data.shape

# %%
# Guardar el dataframe depurado
data.to_csv('peliculaslimpias.csv', index=False)
