# %%
import pandas as pd
import numpy as np
# Cargar el archivo CSV
data = pd.read_csv('concerts.csv')

# %%
data
# Out:
#                        Date          Location    Time  \
# 0      1842-12-07T05:00:00Z     Manhattan, NY  8:00PM
# 1      1843-02-18T05:00:00Z     Manhattan, NY  8:00PM
# 2      1843-04-07T05:00:00Z     Manhattan, NY  8:00PM
# 3      1843-04-22T05:00:00Z     Manhattan, NY  8:00PM
# 4      1843-11-18T05:00:00Z     Manhattan, NY     NaN
# ...                     ...               ...     ...
# 21602  2017-06-24T04:00:00Z  East Hampton, NY     NaN
# 21603  2017-07-02T04:00:00Z   Shanghai, CHINA  7:30PM
# 21604  2017-07-03T04:00:00Z   Shanghai, CHINA  7:30PM
# 21605  2017-07-04T04:00:00Z   Shanghai, CHINA  7:30PM
# 21606  2017-07-07T04:00:00Z   Shanghai, CHINA  7:30PM
#
#                                       Venue                      eventType  \
# 0                              Apollo Rooms            Subscription Season
# 1                              Apollo Rooms            Subscription Season
# 2                              Apollo Rooms                        Special
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21607 entries, 0 to 21606
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       21607 non-null  object
#  1   Location   21588 non-null  object
#  2   Time       20836 non-null  object
#  3   Venue      21552 non-null  object
#  4   eventType  21590 non-null  object
#  5   season     21607 non-null  object
#  6   programID  21607 non-null  int64
#  7   orchestra  21605 non-null  object
#  8   id         21607 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 1.5+ MB

# %%
#duplicados
data = data.drop_duplicates()

# %%
#valores vacios
data.isnull()

# %%
data.isnull().sum() 
#contamos cuantos datos tenemos vacios

# %%
data = data.dropna()

# %%
data.shape

# %%
# Guardar el dataframe depurado
data.to_csv('Conciertolimpios.csv', index=False)
